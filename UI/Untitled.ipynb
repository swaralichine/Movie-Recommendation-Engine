# %%
import pandas as pd
# df = pd.read_csv('file2.csv',error_bad_lines=False)
df = pd.read_csv('file2.csv')
df
# Out:
#                                                      0  \
# 0                     Shawshank Redemption, The (1994)
# 1                       Philadelphia Story, The (1940)
# 2                     Shawshank Redemption, The (1994)
# 3                                   Hoop Dreams (1994)
# 4                                   Hoop Dreams (1994)
# 5           Ghost in the Shell (Kôkaku kidôtai) (1995)
# 6                                  Pulp Fiction (1994)
# 7    Dr. Strangelove or: How I Learned to Stop Worr...
# 8                     Shawshank Redemption, The (1994)
# 9                       Philadelphia Story, The (1940)
# 10   Dr. Strangelove or: How I Learned to Stop Worr...
# 11                          Usual Suspects, The (1995)
# 12                    Shawshank Redemption, The (1994)
# 13          Ghost in the Shell (Kôkaku kidôtai) (1995)
# 14   Dr. Strangelove or: How I Learned to Stop Worr...
# 15                      Philadelphia Story, The (1940)
# ...

# %%
data = df.iloc[1]

# %%
data
# Out:
# 0                      Philadelphia Story, The (1940)
# 1                    Streetcar Named Desire, A (1951)
# 2                               Paths of Glory (1957)
# 3                           Lawrence of Arabia (1962)
# 4                             Double Indemnity (1944)
# 5                 Guess Who's Coming to Dinner (1967)
# 6                                 Hustler, The (1961)
# 7                                 Mary and Max (2009)
# 8                       Day of the Doctor, The (2013)
# 9    Three Billboards Outside Ebbing, Missouri (2017)
# Name: 1, dtype: object

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
list(data)
# Out:
# ['Philadelphia Story, The (1940)',
#  'Streetcar Named Desire, A (1951)',
#  'Paths of Glory (1957)',
#  'Lawrence of Arabia (1962)',
#  'Double Indemnity (1944)',
#  "Guess Who's Coming to Dinner (1967)",
#  'Hustler, The (1961)',
#  'Mary and Max (2009)',
#  'Day of the Doctor, The (2013)',
#  'Three Billboards Outside Ebbing, Missouri (2017)']

# %%
pd.unique(df["0"])
# Out:
# array(['Shawshank Redemption, The (1994)',
#        'Philadelphia Story, The (1940)', 'Hoop Dreams (1994)',
#        'Ghost in the Shell (Kôkaku kidôtai) (1995)',
#        'Pulp Fiction (1994)',
#        'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)',
#        'Usual Suspects, The (1995)',
#        'Star Wars: Episode IV - A New Hope (1977)', 'Crumb (1994)',
#        'His Girl Friday (1940)', 'Heat (1995)', 'Notorious (1946)',
#        'Toy Story (1995)',
#        'Wallace & Gromit: The Best of Aardman Animation (1996)',
#        'Godfather, The (1972)', 'Secrets & Lies (1996)',
#        'In the Name of the Father (1993)', 'Paths of Glory (1957)',
#        'Rebecca (1940)', "Schindler's List (1993)",
#        'Three Colors: Red (Trois couleurs: Rouge) (1994)',
#        'Casablanca (1942)', 'Ran (1985)', 'Third Man, The (1949)',
#        'Rear Window (1954)',
#        'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)'], dtype=object)

# %%
df['0'].value_counts().idxmax()
# Out:
# 'Shawshank Redemption, The (1994)'

# %%
df['1'].value_counts().idxmax()
# Out:
# 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)'

# %%
df["0"].value_counts()
# Out:
# Shawshank Redemption, The (1994)                                               220
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)    126
# Ghost in the Shell (Kôkaku kidôtai) (1995)                                      69
# Pulp Fiction (1994)                                                             40
# Hoop Dreams (1994)                                                              35
# Philadelphia Story, The (1940)                                                  31
# Wallace & Gromit: The Best of Aardman Animation (1996)                          22
# Star Wars: Episode IV - A New Hope (1977)                                       12
# In the Name of the Father (1993)                                                11
# Usual Suspects, The (1995)                                                      11
# Godfather, The (1972)                                                            7
# ...

# %%
df["1"].value_counts()
# Out:
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)    198
# Philadelphia Story, The (1940)                                                 100
# Ghost in the Shell (Kôkaku kidôtai) (1995)                                      62
# Shawshank Redemption, The (1994)                                                44
# His Girl Friday (1940)                                                          42
# Godfather, The (1972)                                                           42
# Wallace & Gromit: The Best of Aardman Animation (1996)                          20
# Rear Window (1954)                                                              20
# Streetcar Named Desire, A (1951)                                                19
# Notorious (1946)                                                                12
# Secrets & Lies (1996)                                                           10
# ...

# %%
df["2"].value_counts()
# Out:
# Philadelphia Story, The (1940)                                                 110
# His Girl Friday (1940)                                                          91
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)     71
# Streetcar Named Desire, A (1951)                                                70
# Rear Window (1954)                                                              69
# Godfather, The (1972)                                                           67
# Notorious (1946)                                                                25
# Paths of Glory (1957)                                                           21
# Secrets & Lies (1996)                                                           16
# Ghost in the Shell (Kôkaku kidôtai) (1995)                                      11
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)                                    9
# ...

# %%
df["3"].value_counts()
# Out:
# Streetcar Named Desire, A (1951)                                                                                      152
# His Girl Friday (1940)                                                                                                133
# Paths of Glory (1957)                                                                                                  63
# Rear Window (1954)                                                                                                     51
# Philadelphia Story, The (1940)                                                                                         33
# Notorious (1946)                                                                                                       29
# Godfather, The (1972)                                                                                                  26
# Lawrence of Arabia (1962)                                                                                              23
# ...

# %%
df["4"].value_counts()
# Out:
# Streetcar Named Desire, A (1951)                                                  180
# Paths of Glory (1957)                                                             135
# Lawrence of Arabia (1962)                                                          77
# His Girl Friday (1940)                                                             65
# Ran (1985)                                                                         20
# Rear Window (1954)                                                                 15
# Secrets & Lies (1996)                                                              14
# Philadelphia Story, The (1940)                                                     11
# Guess Who's Coming to Dinner (1967)                                                 8
# Seventh Seal, The (Sjunde inseglet, Det) (1957)                                     6
# Monty Python and the Holy Grail (1975)                                              6
# ...

# %%
df["5"].value_counts()
# Out:
# Lawrence of Arabia (1962)                                                         154
# Paths of Glory (1957)                                                             140
# Streetcar Named Desire, A (1951)                                                   84
# Ran (1985)                                                                         50
# Seventh Seal, The (Sjunde inseglet, Det) (1957)                                    36
# Guess Who's Coming to Dinner (1967)                                                15
# Touch of Evil (1958)                                                               10
# Fight Club (1999)                                                                   9
# Double Indemnity (1944)                                                             8
# Apocalypse Now (1979)                                                               8
# Yojimbo (1961)                                                                      6
# ...

# %%
df["6"].value_counts()
# Out:
# Lawrence of Arabia (1962)                                                         138
# Guess Who's Coming to Dinner (1967)                                                79
# Ran (1985)                                                                         78
# Seventh Seal, The (Sjunde inseglet, Det) (1957)                                    57
# Paths of Glory (1957)                                                              54
# Fight Club (1999)                                                                  25
# Touch of Evil (1958)                                                               17
# Man Bites Dog (C'est arrivé près de chez vous) (1992)                              16
# Double Indemnity (1944)                                                            12
# Yojimbo (1961)                                                                     12
# Hustler, The (1961)                                                                11
# ...

# %%
df["7"].value_counts()
# Out:
# Guess Who's Coming to Dinner (1967)                                               203
# Fight Club (1999)                                                                  49
# Ran (1985)                                                                         43
# Lawrence of Arabia (1962)                                                          43
# Hustler, The (1961)                                                                37
# Grave of the Fireflies (Hotaru no haka) (1988)                                     32
# Seventh Seal, The (Sjunde inseglet, Det) (1957)                                    28
# Outlaw Josey Wales, The (1976)                                                     18
# Man Bites Dog (C'est arrivé près de chez vous) (1992)                              15
# Touch of Evil (1958)                                                               13
# Double Indemnity (1944)                                                            12
# ...

# %%
df["8"].value_counts()
# Out:
# Guess Who's Coming to Dinner (1967)                                                                                   209
# Day of the Doctor, The (2013)                                                                                          99
# Grave of the Fireflies (Hotaru no haka) (1988)                                                                         68
# Hustler, The (1961)                                                                                                    36
# Outlaw Josey Wales, The (1976)                                                                                         25
# Neon Genesis Evangelion: The End of Evangelion (Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni) (1997)     20
# Mary and Max (2009)                                                                                                    17
# There Will Be Blood (2007)                                                                                             16
# ...

# %%
df["9"].value_counts()
# Out:
# Three Billboards Outside Ebbing, Missouri (2017)                                                                      455
# Day of the Doctor, The (2013)                                                                                          55
# Guess Who's Coming to Dinner (1967)                                                                                    27
# Grave of the Fireflies (Hotaru no haka) (1988)                                                                         13
# Neon Genesis Evangelion: The End of Evangelion (Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni) (1997)     10
# Departed, The (2006)                                                                                                    7
# Hustler, The (1961)                                                                                                     6
# There Will Be Blood (2007)                                                                                              5
# ...

# %%
data = df.iloc[0]
data
# Out:
# 0                     Shawshank Redemption, The (1994)
# 1    Wallace & Gromit: The Best of Aardman Animatio...
# 2    Dr. Strangelove or: How I Learned to Stop Worr...
# 3                                Godfather, The (1972)
# 4                       Philadelphia Story, The (1940)
# 5                                   Rear Window (1954)
# 6        Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# 7                       Outlaw Josey Wales, The (1976)
# 8                                 Departed, The (2006)
# 9     Three Billboards Outside Ebbing, Missouri (2017)
# Name: 0, dtype: object

# %%
data = list(data)
data
# Out:
# ['Shawshank Redemption, The (1994)',
#  'Wallace & Gromit: The Best of Aardman Animation (1996)',
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)',
#  'Godfather, The (1972)',
#  'Philadelphia Story, The (1940)',
#  'Rear Window (1954)',
#  'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)',
#  'Outlaw Josey Wales, The (1976)',
#  'Departed, The (2006)',
#  'Three Billboards Outside Ebbing, Missouri (2017)']

# %%
data = list(df.iloc[3])
data
# Out:
# ['Hoop Dreams (1994)',
#  'Shawshank Redemption, The (1994)',
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)',
#  'His Girl Friday (1940)',
#  'Streetcar Named Desire, A (1951)',
#  'Paths of Glory (1957)',
#  'Lawrence of Arabia (1962)',
#  'Five Easy Pieces (1970)',
#  "Man Bites Dog (C'est arrivé près de chez vous) (1992)",
#  "Guess Who's Coming to Dinner (1967)"]

# %%
data = list(df.iloc[6])
data
# Out:
# ['Pulp Fiction (1994)',
#  'Shawshank Redemption, The (1994)',
#  'Ghost in the Shell (Kôkaku kidôtai) (1995)',
#  'Philadelphia Story, The (1940)',
#  'Streetcar Named Desire, A (1951)',
#  'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)',
#  'Lawrence of Arabia (1962)',
#  'Matrix, The (1999)',
#  "Guess Who's Coming to Dinner (1967)",
#  'Three Billboards Outside Ebbing, Missouri (2017)']

# %%
data = list(df.iloc[9])
data
# Out:
# ['Philadelphia Story, The (1940)',
#  'Streetcar Named Desire, A (1951)',
#  'Paths of Glory (1957)',
#  'Ran (1985)',
#  'Doctor Zhivago (1965)',
#  "Guess Who's Coming to Dinner (1967)",
#  "Kelly's Heroes (1970)",
#  'Legend of Drunken Master, The (Jui kuen II) (1994)',
#  'In the Mood For Love (Fa yeung nin wa) (2000)',
#  'Baby Driver (2017)']

# %%
dff = pd.read_csv("images_url.csv", encoding = "ISO-8859-1")

# %%
dff.head()
# Out:
#                                                Movie  \
# 0                   Shawshank Redemption, The (1994)
# 1  Dr. Strangelove or: How I Learned to Stop Worr...
# 2         Ghost in the Shell (Kôkaku kidôtai) (1995)
# 3                                Pulp Fiction (1994)
# 4                     Philadelphia Story, The (1940)
#
#                                             Location
# 0     \static\img\portfolio\shawshank_redemption.jpg
# 1  \static\img\portfolio\Dr. Strangelove or How I...
# 2       \static\img\portfolio\Ghost in the Shell.jpg
# 3      \static\img\portfolio\Pulp Fiction (1994).jpg
# 4       \static\img\portfolio\Philadelphia Story.jpg

# %%
data2 = dff.values.tolist()

# %%
data2
# Out:
# [['Shawshank Redemption, The (1994)',
#   '\\static\\img\\portfolio\\shawshank_redemption.jpg'],
#  ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)',
#   '\\static\\img\\portfolio\\Dr. Strangelove or How I Learned to Stop Worrying and Love the Bomb (1964).jpg'],
#  ['Ghost in the Shell (Kôkaku kidôtai) (1995)',
#   '\\static\\img\\portfolio\\Ghost in the Shell.jpg'],
#  ['Pulp Fiction (1994)', '\\static\\img\\portfolio\\Pulp Fiction (1994).jpg'],
#  ['Philadelphia Story, The (1940)',
#   '\\static\\img\\portfolio\\Philadelphia Story.jpg'],
#  ['Godfather, The (1972)', '\\static\\img\\portfolio\\Godfather.jpg'],
#  ['His Girl Friday (1940)',
#   '\\static\\img\\portfolio\\His Girl Friday (1940).jpg'],
#  ['Streetcar Named Desire, A (1951)',
#   '\\static\\img\\portfolio\\Streetcar Named Desire, A (1951).jpg'],
#  ['Rear Window (1954)', '\\static\\img\\portfolio\\Rear Window (1954).jpg'],
# ...

# %%
if 'Shawshank Redemption, The (1994)' in data2[0]:
    print("True")
else:
    print("False")
# Out:
# True

# %%
print(data)
print("lets find")
for x in data:
    for y in data2:
        if str(x) in y:
            print(y[1])
# Out:
# ['Philadelphia Story, The (1940)', 'Streetcar Named Desire, A (1951)', 'Paths of Glory (1957)', 'Ran (1985)', 'Doctor Zhivago (1965)', "Guess Who's Coming to Dinner (1967)", "Kelly's Heroes (1970)", 'Legend of Drunken Master, The (Jui kuen II) (1994)', 'In the Mood For Love (Fa yeung nin wa) (2000)', 'Baby Driver (2017)']
# lets find
# \static\img\portfolio\Philadelphia Story.jpg
# \static\img\portfolio\Streetcar Named Desire, A (1951).jpg
# \static\img\portfolio\Paths of Glory (1957).jpg
# \static\img\portfolio\Ran (1985).jpg
# \static\img\portfolio\Guess Who's Coming to Dinner (1967).jpg
# \static\img\portfolio\Legend of Drunken Master, The (Jui kuen II) (1994).jpg
# \static\img\portfolio\Baby Driver (2017).jpg

# %%
dff.ix[7]
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Shawshank Redemption, The (1994)                                            Rear Window (1954)
# \static\img\portfolio\shawshank_redemption.jpg    \static\img\portfolio\Rear Window (1954).jpg
# Name: 7, dtype: object

# %%
df.values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-57e850d2cc5f> in <module>
# ----> 1 df.values()
#
# TypeError: 'numpy.ndarray' object is not callable
